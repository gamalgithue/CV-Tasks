# %%
from ultralytics import YOLO

import matplotlib.pyplot as plt

model = YOLO(r"D:\Subject\Computer Vision\Sections\yolov8n-seg.pt")  

results = model(r"D:\Subject\Computer Vision\Sections\car.jpg")  

result_img = results[0].plot()

plt.imshow(result_img)

plt.axis('off')

plt.show()
# Out:
# image 1/1 D:\Subject\Computer Vision\Sections\car.jpg: 448x640 9 cars, 1 train, 1 truck, 291.8ms
# Speed: 3.0ms preprocess, 291.8ms inference, 10.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
from ultralytics import YOLO

import matplotlib.pyplot as plt

model = YOLO(r"D:\Subject\Computer Vision\Sections\yolov8n-seg.pt")  

results = model(r"D:\Subject\Computer Vision\Sections\football1.mp4")  

result_img = results[0].plot()

plt.imshow(result_img)

plt.axis('off')

plt.show()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/242) D:\Subject\Computer Vision\Sections\football1.mp4: 384x640 3 persons, 2 sports balls, 91.6ms
# video 1/1 (frame 2/242) D:\Subject\Computer Vision\Sections\football1.mp4: 384x640 3 persons, 2 sports balls, 77.8ms
# video 1/1 (frame 3/242) D:\Subject\Computer Vision\Sections\football1.mp4: 384x640 3 persons, 1 sports ball, 85.2ms
# ...
