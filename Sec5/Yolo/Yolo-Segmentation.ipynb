# %%
# !pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/898.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/898.7 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/898.7 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/898.7 kB ? eta -:--:--
#    ---------------------- --------------- 524.3/898.7 kB 764.3 kB/s eta 0:00:01
#    -------------------------------------- 898.7/898.7 kB 948.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/203.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/203.0 MB 419.4 kB/s eta 0:08:03
#    ---------------------------------------- 0.5/203.0 MB 419.4 kB/s eta 0:08:03
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load a model (YOLOv8)
model = YOLO(r"D:\Subject\Computer Vision\Sections\yolov8n-seg.pt")  # Make sure the path is correct

# Predict with the model (using an image URL)
results = model(r"D:\Subject\Computer Vision\Sections\cat.jpg")  # This URL points to an image of a bus

result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 D:\Subject\Computer Vision\Sections\cat.jpg: 640x640 1 cat, 1 dog, 332.0ms
# Speed: 22.7ms preprocess, 332.0ms inference, 19.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load a model (YOLOv8)
model = YOLO(r"D:\Subject\Computer Vision\Sections\yolov8n-seg.pt")  # Make sure the path is correct

# Predict with the model (using an image URL)
results = model(r"D:\Subject\Computer Vision\Sections\football1.mp4",save=True)  # This URL points to an image of a bus

result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/242) D:\Subject\Computer Vision\Sections\football1.mp4: 384x640 3 persons, 2 sports balls, 100.0ms
# video 1/1 (frame 2/242) D:\Subject\Computer Vision\Sections\football1.mp4: 384x640 3 persons, 2 sports balls, 92.4ms
# video 1/1 (frame 3/242) D:\Subject\Computer Vision\Sections\football1.mp4: 384x640 3 persons, 1 sports ball, 95.3ms
# ...
